# %% [markdown]
# # Matplotlib

# %% [markdown]
# # Matplotlib is one of the most popular Python packages used for data visualization. It is a cross-platform library for making 2D plots from data in arrays.
#
#
# # Matplotlib is an open-source drawing library that supports various drawing types
# # You can generate plots, histograms, bar charts, and other types of charts with just a few lines of code

# %% [markdown]
# # Matplotlib is written in Python and makes use of NumPy, the numerical mathematics extension of Python.
#
# # It provides an object-oriented API that helps in embedding plots in applications using Python GUI toolkits such as PyQt, WxPythonotTkinter.
#
# # It can be used in Python and IPython shells, Jupyter notebook and web application servers also.

# %% [markdown]
# # Matplotlib was originally written by John D. Hunter in 2003. The current stable version is 3.5.1 December 11, 2021.

# %% [markdown]
# # Let's install Matplotlib

# %%
pip install matplotlib

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Intro to pyplot
#
# # matplotlib.pyplot is a collection of functions. Each pyplot function makes some change to a figure:
# # e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %% [markdown]
# # 📊 The core architecture of Matplotlib
#
#
# # (1) Figure
#
# # The whole window or page that contains everything.
#
# # Think of it as the canvas.

# %%
fig = plt.figure()

# %% [markdown]
# # (2) Axes
#
# # An Axes is the main plotting area of a Matplotlib Figure.
#
# # Each Axes contains:
#
# # Data space (your actual plot)
#
# # two Axis objects (X-axis & Y-axis)
#
# # titles, labels, ticks, legends, grids, spines

# %% [markdown]
# # plt.subplots( ) # most most common method

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])
plt.show()

# %%
ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
# Out:
# Text(4.444444444444445, 0.5, 'Y Axis')

# %% [markdown]
# # Labels & Title

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])


ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")


plt.show()

# %% [markdown]
# # Limits
# # Limits define the minimum and maximum range of the X-axis and Y-axis.
#
# # By default, Matplotlib automatically chooses limits based on your data.

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

fig, ax = plt.subplots()
ax.plot(x, y)

ax.set_xlim(0, 6)   # X-axis from 0 to 6
ax.set_ylim(0, 30)  # Y-axis from 0 to 30

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])


ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")



ax.set_xlim(0, 10)
ax.set_ylim(0, 20)


plt.show()

# %% [markdown]
# # Grid & Spines

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])


ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")



ax.set_xlim(0, 10)
ax.set_ylim(0, 20)



ax.grid(True)
ax.spines['top'].set_visible(False)   # hide top border


plt.show()

# %% [markdown]
# # Ticks

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])


ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")



ax.set_xlim(0, 10)
ax.set_ylim(0, 20)



ax.grid(True)
ax.spines['top'].set_visible(False)   # hide top border



ax.set_xticks([0, 2, 4, 6, 8, 10])
ax.set_xticklabels(["Zero","Two","Four","Six","Eight","Ten"])

plt.show()

# %% [markdown]
# # Legends

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])


ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")



ax.set_xlim(0, 10)
ax.set_ylim(0, 20)



ax.grid(True)
ax.spines['top'].set_visible(False)   # hide top border



ax.set_xticks([0, 2, 4, 6, 8, 10])
ax.set_xticklabels(["Zero","Two","Four","Six","Eight","Ten"])





ax.plot([1,2,3], [2,4,6], label="Line")
ax.legend()




plt.show()

# %% [markdown]
# # Annotations

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()   # one figure, one axes
ax.plot([1,2,3], [2,4,6])


ax.set_title("My Plot")
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")



ax.set_xlim(0, 10)
ax.set_ylim(0, 20)



ax.grid(True)
ax.spines['top'].set_visible(False)   # hide top border



ax.set_xticks([0, 2, 4, 6, 8, 10])
ax.set_xticklabels(["Zero","Two","Four","Six","Eight","Ten"])





ax.plot([1,2,3], [2,4,6], label="Line")
ax.legend()



ax.annotate("Peak", xy=(2,4), xytext=(3,6),
            arrowprops=dict(facecolor='black', shrink=0.05))


plt.show()

# %% [markdown]
# # (3) Axis
#
# # An Axis in Matplotlib represents the x or y coordinate system within an Axes.
#
# # Each Axes has two Axis objects:
#
# # XAxis
#
# # YAxis

# %% [markdown]
# # # Components of an Axis

# %% [markdown]
# # {1} Ticks → the little marks along the axis (0, 1, 2, 3 ...)
#
# # {2} Tick Labels → the text shown at tick marks (Jan, Feb, Mar ...)
#
# # {3} Scale → linear, log, symlog, logit
#
# # {4} Grid lines (optional)
#
# # {5} Formatter & Locator (for customizing labels & intervals)

# %% [markdown]
# # Setting Labels

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,6])

ax.set_xlabel("X Axis Label")
ax.set_ylabel("Y Axis Label")
plt.show()

# %% [markdown]
# # Setting Limits

# %%
ax.set_xlim(0, 5)   # X Axis range
ax.set_ylim(0, 10)  # Y Axis range
# Out:
# (0.0, 10.0)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,6])

ax.set_xlabel("X Axis Label")
ax.set_ylabel("Y Axis Label")


ax.set_xlim(0, 5)   # X Axis range
ax.set_ylim(0, 10)  # Y Axis range

plt.show()

# %% [markdown]
# # Working with Ticks

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,6])

ax.set_xlabel("X Axis Label")
ax.set_ylabel("Y Axis Label")


ax.set_xlim(0, 5)   # X Axis range
ax.set_ylim(0, 10)  # Y Axis range


ax.set_xticks([0,1,2,3,4,5])
ax.set_yticks([0,2,4,6,8,10])


plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,6])

ax.set_xlabel("X Axis Label")
ax.set_ylabel("Y Axis Label")


ax.set_xlim(0, 5)   # X Axis range
ax.set_ylim(0, 10)  # Y Axis range


ax.set_xticks([1,2,3])
ax.set_xticklabels(["One", "Two", "Three"])

plt.show()

# %% [markdown]
# # Tick Parameters (Appearance)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,6])

ax.set_xlabel("X Axis Label")
ax.set_ylabel("Y Axis Label")


ax.set_xlim(0, 5)   # X Axis range
ax.set_ylim(0, 10)  # Y Axis range


ax.set_xticks([1,2,3])
ax.set_xticklabels(["One", "Two", "Three"])



ax.tick_params(axis="x", colors="red", direction="in", length=6)
ax.tick_params(axis="y", colors="blue", rotation=45)

plt.show()

# %% [markdown]
# # Axis Scale

# %%
import numpy as np    #✅ Logarithmic
x = np.linspace(0.1, 10, 100)
y = np.exp(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_yscale("log")   # log scale on Y-axis

# %%
import numpy as np     #✅ Symmetric Log
x = np.linspace(0.1, 10, 100)
y = np.exp(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.set_yscale("log")
ax.set_xscale("symlog", linthresh=0.1)

# %%
import numpy as np     #✅ Logit
x = np.linspace(0.1, 10, 100)
y = np.exp(x)

fig, ax = plt.subplots()

ax.plot(x, y)
ax.set_yscale("log")
ax.set_xscale("logit")

# %% [markdown]
# # Artist
# # Basically, everything visible on the Figure is an Artist . This includes Text objects, Line2D objects, collections objects, Patch objects, etc.
#
# # When the Figure is rendered, all of the Artists are drawn to the canvas. Most Artists are tied to an Axes; such an Artist cannot be shared by multiple Axes, or moved from one to another.

# %%
Figure (Artist)
 ├── Axes (Artist)
 │    ├── Axis (x & y) (Artist)
 │    │     └── Tick (Artist)
 │    ├── Lines (Line2D Artist)
 │    ├── Texts (Title, labels, etc.)
 │    ├── Patches (bars, hist shapes, etc.)
 │    └── Legend (Artist)
 └── Other global artists
# Out:
#   File "/tmp/ipython-input-2150605440.py", line 2
#     ├── Axes (Artist)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # Line2D Artist

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
line, = ax.plot([1,2,3], [2,4,6])  # Line2D Artist
print(type(line))

# %% [markdown]
# # Text Artist

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
line, = ax.plot([1,2,3], [2,4,6])  # Line2D Artist
print(type(line))

txt = ax.set_title("My Title")   # Text Artist
print(type(txt))  # <class 'matplotlib.text.Text'>

# %% [markdown]
# # Patch Artist

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
line, = ax.plot([1,2,3], [2,4,6])  # Line2D Artist
print(type(line))

txt = ax.set_title("My Title")   # Text Artist
print(type(txt))  # <class 'matplotlib.text.Text'>


rect = plt.Rectangle((0.2,0.2), 0.4, 0.4, color="orange")
ax.add_patch(rect)  # Patch Artist

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle, Polygon, Wedge, FancyBboxPatch, FancyArrowPatch

fig, ax = plt.subplots()
ax.add_patch(Rectangle((1, 1), 2, 0.8))     # (x, y, width, height) in data units
ax.add_patch(Circle((4, 2), 0.7))           # (x, y, radius)
ax.add_patch(Polygon([[6,1],[6.8,2.2],[5.4,2.0]]))  # arbitrary vertices
ax.add_patch(Wedge(center=(2.5,3.2), r=0.9, theta1=20, theta2=140))
ax.set_xlim(0, 8); ax.set_ylim(0, 4)
plt.show()

# %% [markdown]
# # Key Methods of Artist
#
# # Every Artist shares these:
#
# # set_*( ) → modify properties
#
# # get_*( ) → retrieve properties

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
line, = ax.plot([1,2,3], [2,4,6])  # Line2D Artist
print(type(line))

txt = ax.set_title("My Title")   # Text Artist
print(type(txt))  # <class 'matplotlib.text.Text'>


line.set_color("red")
line.set_linestyle("--")
print(line.get_linewidth())

# %% [markdown]
# # Parts of a Figure

# %% [markdown]
# ![Screenshot%202022-04-15%20at%2012.58.20%20PM.png](attachment:Screenshot%202022-04-15%20at%2012.58.20%20PM.png)

# %% [markdown]
# The whole figure. The Figure keeps track of all the child Axes, a group of 'special' Artists (titles, figure legends, colorbars, etc), and even nested subfigures.
#
# The easiest way to create a new Figure is with pyplot:

# %% [markdown]
# # Sub Plots-
# # Subplots ( ) is a Matplotlib function that is used to display multiple plots in one figure. It takes various arguments such as a number of rows, columns, or x, y axis.

# %% [markdown]
# # Plt.subplots(nrows, ncols)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (20,7))  # an empty figure with no Axes
fig = plt.subplots()  # a figure with a single Axes

fig = plt.subplots(2,2)  # a figure with a 2x2 grid of Axes

fig = plt.subplots(2,3)  # a figure with a 2x3 grid of Axes

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]


plt.figure(figsize=(20, 6))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)



plt.suptitle('Categorical Plotting')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]


plt.figure(figsize=(20, 6))

plt.subplot(231)
plt.bar(names, values)

plt.subplot(232)
plt.scatter(names, values)

plt.subplot(233)
plt.plot(names, values)

plt.subplot(234)
plt.plot(names, values)

plt.subplot(235)
plt.bar(names, values)

plt.subplot(236)
plt.scatter(names, values)


plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# # subplot(nrows, ncols, plot_number)
#
# # plt.subplot takes three arguments, the number of rows (nrows), the number of columns (ncols) and the plot number.
#
# # Using the 3-digit code is a convenience function provided for when nrows, ncols and plot_number are all <10.
#
# # So, 131 is equivalent to nrows=1, ncols=3, plot_number=1

# %% [markdown]
# # plt.subplot(1, 2, 1)
# # the figure has 1 row, 2 columns, and this plot is the first plot.

# %% [markdown]
# # plt.subplot(1, 2, 2)
# # the figure has 1 row, 2 columns, and this plot is the second plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # Bar Label Demo
# This example shows how to use the bar_label helper function to create bar chart labels.
#
# See also the grouped bar, stacked bar and horizontal bar chart examples.

# %% [markdown]
# # The matplotlib API in Python provides the bar() function which can be used in MATLAB style use or as an object-oriented API. The syntax of the bar() function to be used with the axes is as follows:-
#
# plt.bar(x, height, width, bottom, align)
#
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)

# %% [markdown]
# x: representing the coordinates of the x-axis
#
# height: the height of the bars
#
# width: width of the bars. Its default value is 0.8
#
# bottom: It’s optional. It is a y-coordinate of the bar its default value is None
#
# align: center, edge its default value is center

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_csv("/Users/mac/Desktop/RnW/PYTHON/Seaborn+matplotlib/Dataset/antic_cars.csv")
df = pd.DataFrame(data)
print(df)

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
pd.read_csv("/Users/mac/Desktop/RnW/PYTHON/Seaborn+matplotlib/Dataset/antic_cars.csv")

# %%
model = df['Model'].head(12)
year = df['Year'].head(12)


# Figure Size
fig = plt.figure(figsize =(40, 10))

# Horizontal Bar Plot
plt.bar(model[0:4], year[0:4])

# Show Plot
plt.show()

# %%
#define array
data = [5. , 25. , 50. , 20.]
plt.bar(data,color='c',height=7,width = 4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.arange(4)
turnover = [12, 34, 31, 20]

plt.bar(x, turnover, width=0.4)
plt.xticks(np.arange(4), ('apple', 'banana', 'cherry', 'mango'))
plt.xlabel('Product')
plt.ylabel('Turnover')

plt.show()

# %% [markdown]
# # Grouped bar chart

# %% [markdown]
# # Bar graphs can also be used for more complex comparisons of data with grouped bar charts and stacked bar charts.
#
# # In a grouped bar chart, for each categorical group there are two or more bars. These bars are color-coded to represent a particular grouping.

# %%
year_1 = (20, 35, 30, 35, 27, 27, 33)
year_2 = (25, 39, 45, 25, 21, 29, 36)

ind = np.arange(7) #produces an array of integers starting from 0 up to (but not including) 7.
width = 0.35

fig, ax = plt.subplots()

rects1 = ax.bar(ind - width / 2, year_1,width, color='#1f77b4', alpha=0.5)
rects2 = ax.bar(ind + width / 2, year_2,width, color='#1f77b4')

plt.legend((rects1[4], rects2[4]), ('year_1', 'year_2'))

plt.show()

# alpha - Transparency level (1 = solid, 0 = fully transparent). Here it’s 50% transparent.

# %% [markdown]
# # This plot compares monthly turnover of year_1 to year_2.
#
# # Except for April and May, monthly turnover in year_2 is higher than year_1.
#
# # In the case of retailing, this kind of changes can be explained like the strategy of year N works well, or new products attract clients, or new stores of year N contribute to the turnover.

# %% [markdown]
# # Stacked bar chart

# %%
cheese = (20, 35, 30, 35, 27, 37, 20)
non_cheese = (25, 32, 34, 20, 25, 17, 29)


plt.figure(figsize =(20, 7))


rect1 = plt.bar(np.arange(7), cheese, width=0.4, color='orangered')
rect2 = plt.bar(np.arange(7), non_cheese,  bottom=cheese, width=0.4, color='#1f77b4') # must include bottom

plt.show()

# %% [markdown]
# # Horizontal bar chart

# %%
df = pd.DataFrame({'product': ['grill', 'cheese', 'red wine', 'salade','chicken', 'sushi', 'pizza', 'soup'],
                   'turnover': [846, 739, 639, 593, 572, 493, 428, 293]},
                    columns=['product', 'turnover'])

df.sort_values('turnover', inplace=True)

# df.reset_index(inplace=True, drop=True)

plt.figure(figsize =(20, 7))


plt.barh(np.arange(len(df['product'])), df['turnover'], align='center')

plt.yticks(np.arange(len(df['product'])), df['product'])

plt.tick_params(labelsize=12)

plt.xlabel('Turnover(k euros)', fontdict={'fontsize': 13})

#{'fontsize': 13, 'fontweight': 'bold', 'color': 'blue'}.

plt.ylabel('Product', fontdict={'fontsize': 13})

plt.show()

# %% [markdown]
# # Line chart

# %% [markdown]
# # A line chart or line graph is a type of chart which displays information as a series of data points called ‘markers’ connected by straight line segments.
#
# # A line chart is often used to visualize a trend in data over intervals of time – a time series – thus the line is often drawn chronologically.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

turnover = [2, 7, 14, 17, 20, 27, 30, 38, 25, 18, 6, 1]
plt.plot(np.arange(12), turnover, marker='.')

#plt.figure(figsize =(20, 7))

plt.tick_params(labelsize=12)

plt.xticks(np.arange(12),np.arange(1,13))

plt.xlabel('Month', size=12)

plt.ylabel('Turnover of ice-cream', size=12)


plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# # Suppose that the plot above describes the turnover of ice-cream’s sales during one year.
#
# # According to the plot, we can clearly find that the sales reach a peak in summer, then fall from autumn to winter, which is logical.

# %% [markdown]
# # Line chart with multiple lines

# %%
year_1 = [1.5, 3, 10, 13, 22, 36, 30, 33, 24.5, 15, 6.5, 1.2]
year_2 = [2, 7, 14, 17, 20, 27, 30, 38, 25, 18, 6, 1]

plt.figure(figsize =(20, 7))


plt.plot(np.arange(12), year_1, marker='.', color='#1f77b4',label='year_1', linestyle='--', alpha=0.5)
plt.plot(np.arange(12), year_2, marker='.', color='#1f77b4',label='year_2')
plt.legend()

plt.show()

# %% [markdown]
# # As an extension of the first plot, the second one compares two-year turnover together. The peak for both year is in the summer, for year_2, the peak is in August; however, the peak is reached in June in the year_1, which is caused by the heatwave in June.

# %% [markdown]
# # Add values’ label on the plot

# %% [markdown]
# # We find that there is no parameter for add values’ labels by plt.plot(), but we can add them with text() function.

# %% [markdown]
# # Histogram-
# The most common graph for displaying frequency distributions is a histogram. To create a histogram the first step is to create a bin of ranges, then distribute the whole range of value into series of intervals, and count the value which will fall in the given interval. we can use plt.hist() function for plotting the histograms which will take various arguments like data, bins, color, etc.
#
# x: x-coordinate or sequence of the array
#
# bins: integer value for the number of bins wanted in the graph
#
# range: the lower and upper range of bins
#
# density: optional parameter that contains boolean values
#
# histtype: optional parameter used to create different types of histograms like:-bar, bar stacked, step, step filled and the default is a bar

# %%
#draw random samples from random distributions.
x = np.random.normal(170, 20, 250)
#plot histograms
plt.hist(x)
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# Read CSV into pandas
data = pd.read_csv("/Users/mac/Desktop/ROBOSTASH/Upskillz/panda_file/Salary_Data.csv")
df = pd.DataFrame(data)
print(df)

# %%
YE = df['YearsExperience'].head(20)
plt.hist(YE)

# %%
S = df['Salary'].head(20)
plt.hist(S)

# %% [markdown]
# # Scatter Plot-
#
# A scatter plot (also called a scatter graph, scatter chart, scattergram, or scatter diagram) is a type of plot or mathematical diagram using Cartesian coordinates to display values for typically two variables for a set of data.
# Scatter plots are used to show the relationships between the variables and use the dots for the plotting or it used to show the relationship between two numeric variables.
#
# The scatter() method in the Matplotlib library is used for plotting.

# %% [markdown]
# Scatter plots are used when you want to show the relationship between two variables. Scatter plots are sometimes called correlation plots because they show how two variables are correlated.

# %%
#create the x and y axis coordinates
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,label = '2022')

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Matrix")

plt.legend()
plt.show()

# %%
turnover = [30, 38, 26, 20, 21, 15, 8, 5, 3, 9, 25, 27]
plt.plot(np.arange(12), turnover, marker='o')

plt.show()

# %% [markdown]
# # Suppose that the plot above describes the turnover of hot soup’s sales during one year. According to the plot, we can clearly find that the sales reach a peak in winter, then fall from spring to summer, which is logical.

# %%
plt.scatter(x,y, color='r')
plt.scatter(y,x, color='b')

# %% [markdown]
# # Scatter plot with different colors

# %% [markdown]
# # Scatter plot which created by matplotlib, cannot specify colors in terms of category variable’s value. So we have to overlap plots of different colors.

# %%
plt.scatter(x=range(40, 70, 1),y=np.abs(np.random.randn(30)*20),s=200, alpha=0.6,label='40-69 years old')

plt.scatter(x=range(20, 40, 1),y=np.abs(np.random.randn(20)*40),s=200, alpha=0.6,label='20-39 years old')

plt.show()

# %% [markdown]
# # This 2-color scatter plot displays clearly the difference of weekly purchase cost between young people and middle aged or elderly people: average weekly purchase of younger people is nealy once more than middle aged or elderly people.

# %% [markdown]
# # Pie Chart-
# A pie chart (or circular chart ) is used to show the percentage of the whole. Hence it is used when we want to compare the individual categories with the whole. Pie() will take the different parameters such as:
#
# x: Sequence of an array
#
# labels: List of strings which will be the name of each slice in the pie chart
#
# Autopct: It is used to label the wedges with numeric values. The labels will be placed inside the wedges. Its format is %1.2f%

# %%
#define the figure size
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
x = [25,30,45,10]
#labels of the pie chart
labels = ['A','B','C','D']
plt.legend()

plt.pie(x, labels=labels)
plt.show()
# Out:
# /tmp/ipython-input-2316667275.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

labels = 'apple', 'banana', 'cherry', 'durian', 'elderberries', 'figs', 'grapes'
sizes = [32, 20, 15, 10, 10, 8, 5]

p = plt.pie(sizes, labels=labels, explode=(0.07, 0, 0, 0, 0, 0, 0), autopct='%1.1f%%', startangle=0, shadow=True)


plt.axis('equal')

for i, (apple, banana, cherry, durian, elderberries, figs, grapes) in enumerate(p):
    if i > 0:
        apple.set_fontsize(12)
        banana.set_fontsize(12)
        cherry.set_fontsize(12)
        durian.set_fontsize(12)
        elderberries.set_fontsize(12)
        figs.set_fontsize(12)
        grapes.set_fontsize(12)

plt.show()

# %% [markdown]
# # This pie chart describes the turnovers’ percentage for each fruit. Sales of apple bring the most turnover among 7 fruits, who presents 32% of turnover. If the values represent volume instead of turnover, then we should prepare more apples than other fruits in the store.

# %% [markdown]
# # Donut chart

# %% [markdown]
# #A donut chart is a variant of the pie chart, with a blank center allowing for additional information about the data as a whole to be included. This type of circular graph can support multiple statistics at once and it provides a better data intensity ratio to standard pie charts. It does not have to contain information in the center.

# %%
my_circle = plt.Circle((0, 0), 0.7, color='white')
sizes = [32, 20, 15, 10, 10, 8, 5]


d = plt.pie(sizes, labels=labels, autopct='%1.1f%%',startangle=90, labeldistance=1.05)
plt.axis('equal')
plt.gca().add_artist(my_circle)

plt.show()

# %% [markdown]
# # Nested pie chart

# %% [markdown]
# #A nested pie chart or multi-level pie chart allows you to incorporate multiple levels or layers into your pie. Nested pies are a module variation on our standard pie chart type.

# %%
labels = ['vegetable', 'fruit']

sizes = [300, 200]

labels_vegefruit = ['potato', 'tomato', 'onion', 'apple','banana', 'cherry', 'durian']

sizes_vegefruit = [170, 70, 60, 70, 60, 50, 20]

colors = ['#FFB600', '#09A0DA']

colors_vegefruit = ['#FFCE53', '#FFDA7E', '#FFE9B2', '#30B7EA','#56C7F2','#7FD6F7', '#B3E7FB']

bigger = plt.pie(sizes, labels=labels, colors=colors,startangle=90, frame=True)

smaller = plt.pie(sizes_vegefruit, labels=labels_vegefruit,colors=colors_vegefruit, radius=0.7, startangle=90, labeldistance=0.7)

centre_circle = plt.Circle((0, 0), 0.4, color='white', linewidth=0)

fig = plt.gcf()

fig.gca().add_artist(centre_circle)

plt.axis('equal')

plt.tight_layout()

plt.show()

# %% [markdown]
# # This chart specifies a second level for consommation of vegetable and fruit, respectively. In general, vegetable is more consummed than fruit. Among three vegetables, potato is much more popular than others; among 4 fruits, apple is the most sold. Thus, for the retailers, they need to prepare more potatoes and apples than other vegetables and fruits.

# %% [markdown]
# # Area Chart-
#  An area chart or area graph displays graphically quantitative data. It is based on the line chart. The area between axis and line are commonly emphasized with colors, textures and hatchings.

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Data
turnover = [2, 7, 14, 17, 20, 27, 30, 38, 25, 18, 6, 1]


plt.fill_between(np.arange(12), turnover, color="skyblue", alpha=0.4)

# linear plottinh
plt.plot(np.arange(12), turnover, color="Slateblue", alpha=0.6, linewidth=2)

plt.tick_params(labelsize=12)

plt.xticks(np.arange(12), np.arange(1,13))

plt.xlabel('Month', size=12)

plt.ylabel('Turnover of ice-cream', size=12)

plt.ylim(bottom=0)

plt.show()

# %% [markdown]
# # Suppose that the plot above describes the turnover of ice-cream’s sales during one year. According to the plot, we can clearly find that the sales reach a peak in summer, then fall from autumn to winter, which is logical.

# %%
year_1 = [1.5, 3, 10, 13, 22, 36, 30, 33, 24.5, 15, 6.5, 1.2]
year_2 = [2, 7, 14, 17, 20, 27, 30, 38, 25, 18, 6, 1]

plt.fill_between(np.arange(12), year_1, color="lightpink", alpha=0.5, label='year 1',linewidth=2)
plt.fill_between(np.arange(12), year_2, color="skyblue", alpha=0.5, label='year 2',linewidth=2)
plt.legend()
plt.show()

# %% [markdown]
# # As an extension of the first plot, the second one compares two-year turnover together. The peak for both year is in the summer, for year-1, the peak is in August; however, the peak is reached in June in the year-2, which is caused by the heatwave in June.

# %% [markdown]
# # Box Plot-
# # A Box plot is used to show the summary of the whole dataset or all the numeric values in the dataset.
#
# # The summary contains minimum, first quartile, median, third quartile, and maximum. Also, the median is present between the first and third quartile. Here x-axis contains the data values and y coordinates show the frequency distribution.
#
# # Parameters used in box plots are as follows:
#
#
# # matplotlib.pyplot.boxplot(data, notch=None, vert=None, patch_artist=None, widths=None)

# %% [markdown]
# # data - array or sequence of array to be plotted
#
# # notch - optional parameter accepts boolean values
#
# # vert - optional parameter accepts boolean values false and true for horizontal and vertical plot respectively
#
# # bootstrap - optional parameter accepts int specifies intervals around notched boxplots
#
# # usermedians - optional parameter accepts array or sequence of array dimension compatible with data
#
# # positions - optional parameter accepts array and sets the position of boxes
#
# # widths - optional parameter accepts array and sets the width of boxes
#
# # patch_artist -  optional parameter having boolean values
#
# # labels - sequence of strings sets label for each dataset
#
# # meanline - optional having boolean value try to render meanline as full width of box
#
# # order - optional parameter sets the order of the boxplot

# %%
#create the random values by using numpy
values= np.random.normal(100, 20, 300)
#creating the plot by boxplot() function which is avilable in matplotlib
plt.boxplot(values,patch_artist=True,vert=True)
plt.show()

# %%
#create the random values by using numpy
values= np.random.normal(100, 20, 300)
#creating the plot by boxplot() function which is avilable in matplotlib
plt.boxplot(values,vert=True)
plt.show()

# %%
# Read CSV into pandas
data = pd.read_csv("/Users/mac/Desktop/ROBOSTASH/Upskillz/panda_file/Salary_Data.csv")
df = pd.DataFrame(data)
print(df)

# %%
S = df['Salary']

#creating the plot by boxplot() function which is avilable in matplotlib
plt.boxplot(S,patch_artist=True,vert=True)
plt.show()

# %% [markdown]
# # 3-D Graphs-
# Now that you have seen some simple graphs it’s time to check some complex ones i.e 3-D graphs. Initially, Matplotlib was built for 2-dimensional graphs but later on, 3-D graphs were added to it. Let’s check how you can plot a 3-D graph in Matplotlib.

# %%
from mpl_toolkits import mplot3d

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# %% [markdown]
# # Each and every plot that we have seen in 2-D plotting through Matplotlib can be drawn as 3-D graphs also.

# %% [markdown]
# # Also here we discussed how to customize the figure or how to resize it and also how to decorate the plots by using the various arguments. Since now you know the basics of plotting and charting you can try plotting different datasets and mathematical functions

# %% [markdown]
# # As Data Professionals (including Data Analysts, Data Scientists, ML Engineers, DL Engineers) at some point all of them need to visualize data and present findings so what would be a better option than it gives you good confidence in the industry.

# %%
pip install squarify

# %%
import numpy as np
import matplotlib.pyplot as plt
import squarify

volume = [350, 220, 170, 150, 50]
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k',
          'Sugar\n volume: 170k', 'Frozen\n volume: 150k',
          'Non-food\n volume: 50k']
color_list = ['#0f7216', '#b2790c', '#ffe9a3',
              '#f9d4d4', '#d35158', '#ea3033']

plt.rc('font', size=14)
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.7)
plt.axis('off')

plt.show()
